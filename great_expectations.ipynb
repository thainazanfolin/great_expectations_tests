# %% [markdown]
# <a href="https://colab.research.google.com/github/thainazanfolin/great_expectations_tests/blob/main/great_expectations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install great_expectations
# Out:
# Requirement already satisfied: great_expectations in /usr/local/lib/python3.11/dist-packages (0.17.21)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (4.2.2)
# Requirement already satisfied: Click!=8.1.4,>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (8.1.8)
# Requirement already satisfied: colorama>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (0.4.6)
# Requirement already satisfied: cryptography>=3.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (43.0.3)
# Requirement already satisfied: Ipython>=7.16.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (7.7.1)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (3.1.6)
# Requirement already satisfied: jsonpatch>=1.22 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (4.23.0)
# Requirement already satisfied: makefun<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.15.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (3.26.1)
# Requirement already satisfied: mistune>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (3.1.3)
# Requirement already satisfied: nbformat>=5.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (5.10.4)
# Requirement already satisfied: notebook>=6.4.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (6.5.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from great_expectations) (24.2)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2.11.3)
# Requirement already satisfied: pyparsing>=2.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2.9.0.post0)
# Requirement already satisfied: pytz>=2021.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2025.2)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2.32.3)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (0.17.17)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.15.2)
# Requirement already satisfied: tqdm>=4.59.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (4.13.2)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (5.3.1)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2.4.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations) (2.1.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from altair<5.0.0,>=4.2.1->great_expectations) (0.12.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.2->great_expectations) (1.17.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations) (3.0.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.10->great_expectations) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch>=1.22->great_expectations) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations) (0.24.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations) (2.21.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations) (5.7.2)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (6.4.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (23.1.0)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (6.1.12)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations) (1.3.0)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->great_expectations) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->great_expectations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->great_expectations) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->great_expectations) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->great_expectations) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.2->great_expectations) (2.22)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (1.8.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations) (5.9.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.0->great_expectations) (4.3.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->Ipython>=7.16.3->great_expectations) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=6.4.10->great_expectations) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great_expectations) (2.7)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations) (1.3.1)

# %% [markdown]
# imports

# %%
import kagglehub
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import great_expectations as ge

# %% [markdown]
# ## 1. Carregando o Dataset
# Carregando o dataset a partir do arquivo raw no github.

# %%
url = 'https://raw.githubusercontent.com/thainazanfolin/great_expectations_tests/refs/heads/main/disney_princess_popularity_dataset_300_rows.csv'
df = pd.read_csv(url)

# visão inicial do df
df.head()
# Out:
#   PrincessName         FirstMovieTitle  FirstMovieYear  MovieRuntimeMinutes  \
# 0   Pocahontas  Pocahontas's Adventure            1977                   85
# 1        Mulan       Mulan's Adventure            1995                   85
# 2         Raya        Raya's Adventure            1989                  110
# 3         Anna        Anna's Adventure            1940                   78
# 4        Mulan       Mulan's Adventure            1943                  103
#
#    NumberOfSongs HasSoloSong HasDuet HairColor EyeColor OutfitPrimaryColor  \
# 0              4          No     Yes     Brown    Green               Pink
# 1              1         Yes     Yes    Blonde    Brown             Purple
# 2              4          No      No    Blonde    Hazel               Pink
# 3              1          No      No     Brown     Grey              Green
# 4              7          No     Yes     White    Brown              Green
#
#    ... RottenTomatoesScore BoxOfficeMillions AvgScreenTimeMinutes  \
# 0  ...                  88               661                   25
# 1  ...                  91               688                   52
# 2  ...                  76               790                   54
# 3  ...                  70               820                   42
# 4  ...                  86               996                   55
#
#   NumMerchItemsOnAmazon GoogleSearchIndex2024 InstagramFanPages  \
# 0                  2524                    68               298
# 1                  4202                    49               133
# 2                   525                    68               129
# 3                  1951                    73               138
# 4                  3958                    34               155
#
#   TikTokHashtagViewsMillions  \
# 0                        481
# 1                        619
# 2                        230
# 3                        697
# 4                        200
#
#                                         Top3Hashtags IsIconic PopularityScore
# 0  #TeamPocahontas #LovePocahontas #PocahontasFor...      Yes              88
# 1                #TeamMulan #LoveMulan #MulanForever      Yes              78
# 2                   #TeamRaya #LoveRaya #RayaForever       No              53
# 3                   #TeamAnna #LoveAnna #AnnaForever      Yes              84
# 4                #TeamMulan #LoveMulan #MulanForever      Yes              71
#
# [5 rows x 36 columns]

# %% [markdown]
# ## 2. Análise exploratória dos dados
# Iniciando a análise exploratória para entender possíveis testes úteis no momento do ETL.

# %%
# número de linhas e colunas
print(f"\nLinhas e colunas: {df.shape[0]} linhas e {df.shape[1]} colunas")

# nomes das colunas
print("\nColunas:")
print(df.columns.tolist())

# tipos de dados e contagem (não nulos)
print("\nInfos:")
print(df.info())

# valores nulos por coluna
print("\nValores nulos por coluna:")
print(df.isnull().sum())

# % de valores nulos
print("\n% de valores nulos por coluna:")
print((df.isnull().mean() * 100).round(2))

# Colunas numéricas
print("\nEstatísticas descritivas (colunas numéricas):")
print(df.describe())

# Colunas categóricas
print("\nEstatísticas descritivas (colunas categóricas):")
print(df.describe(include=['object']))

# Valores únicos por coluna (motivo:útil para saber se precisa validar um domínio fixo)
print("\nValores únicos por coluna categórica:")
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"\nColuna '{col}' - {df[col].nunique()} valores únicos:")
    print(df[col].unique())

# Detecta possíveis colunas com valores duplicados
print("\nRegistros duplicados (linhas inteiras):", df.duplicated().sum())

# Verifica se há colunas que parecem ser identificadores únicos
print("\nColunas com valores únicos em todas as linhas (possíveis IDs):")
for col in df.columns:
    if df[col].is_unique:
        print(f"- {col}")
# Out:
# Linhas e colunas: 300 linhas e 36 colunas
#
# Colunas:
# ['PrincessName', 'FirstMovieTitle', 'FirstMovieYear', 'MovieRuntimeMinutes', 'NumberOfSongs', 'HasSoloSong', 'HasDuet', 'HairColor', 'EyeColor', 'OutfitPrimaryColor', 'OutfitStyleEra', 'IsRoyalByBirth', 'HasAnimalSidekick', 'SidekickType', 'HasMagicalPowers', 'MagicType', 'MainSetting', 'IsBasedOnRealStory', 'CulturalOrigin', 'SpeaksToAnimals', 'FightsVillainDirectly', 'RomanticSubplot', 'MarriedByEnd', 'VillainName', 'VillainType', 'IMDB_Rating', 'RottenTomatoesScore', 'BoxOfficeMillions', 'AvgScreenTimeMinutes', 'NumMerchItemsOnAmazon', 'GoogleSearchIndex2024', 'InstagramFanPages', 'TikTokHashtagViewsMillions', 'Top3Hashtags', 'IsIconic', 'PopularityScore']
#
# Infos:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PrincessName                300 non-null    object
#  1   FirstMovieTitle             300 non-null    object
#  2   FirstMovieYear              300 non-null    int64
#  3   MovieRuntimeMinutes         300 non-null    int64
#  4   NumberOfSongs               300 non-null    int64
#  5   HasSoloSong                 300 non-null    object
#  6   HasDuet                     300 non-null    object
#  7   HairColor                   300 non-null    object
#  8   EyeColor                    300 non-null    object
#  9   OutfitPrimaryColor          300 non-null    object
#  10  OutfitStyleEra              300 non-null    object
#  11  IsRoyalByBirth              300 non-null    object
#  12  HasAnimalSidekick           300 non-null    object
#  13  SidekickType                230 non-null    object
#  14  HasMagicalPowers            300 non-null    object
#  15  MagicType                   247 non-null    object
#  16  MainSetting                 300 non-null    object
#  17  IsBasedOnRealStory          300 non-null    object
#  18  CulturalOrigin              300 non-null    object
#  19  SpeaksToAnimals             300 non-null    object
#  20  FightsVillainDirectly       300 non-null    object
#  21  RomanticSubplot             300 non-null    object
#  22  MarriedByEnd                300 non-null    object
#  23  VillainName                 300 non-null    object
#  24  VillainType                 253 non-null    object
#  25  IMDB_Rating                 300 non-null    float64
#  26  RottenTomatoesScore         300 non-null    int64
#  27  BoxOfficeMillions           300 non-null    int64
#  28  AvgScreenTimeMinutes        300 non-null    int64
#  29  NumMerchItemsOnAmazon       300 non-null    int64
#  30  GoogleSearchIndex2024       300 non-null    int64
#  31  InstagramFanPages           300 non-null    int64
#  32  TikTokHashtagViewsMillions  300 non-null    int64
#  33  Top3Hashtags                300 non-null    object
#  34  IsIconic                    300 non-null    object
#  35  PopularityScore             300 non-null    int64
# dtypes: float64(1), int64(11), object(24)
# memory usage: 84.5+ KB
# None
#
# Valores nulos por coluna:
# PrincessName                   0
# FirstMovieTitle                0
# FirstMovieYear                 0
# MovieRuntimeMinutes            0
# NumberOfSongs                  0
# HasSoloSong                    0
# HasDuet                        0
# HairColor                      0
# EyeColor                       0
# OutfitPrimaryColor             0
# OutfitStyleEra                 0
# IsRoyalByBirth                 0
# HasAnimalSidekick              0
# SidekickType                  70
# HasMagicalPowers               0
# MagicType                     53
# MainSetting                    0
# IsBasedOnRealStory             0
# CulturalOrigin                 0
# SpeaksToAnimals                0
# FightsVillainDirectly          0
# RomanticSubplot                0
# MarriedByEnd                   0
# VillainName                    0
# VillainType                   47
# IMDB_Rating                    0
# RottenTomatoesScore            0
# BoxOfficeMillions              0
# AvgScreenTimeMinutes           0
# NumMerchItemsOnAmazon          0
# GoogleSearchIndex2024          0
# InstagramFanPages              0
# TikTokHashtagViewsMillions     0
# Top3Hashtags                   0
# IsIconic                       0
# PopularityScore                0
# dtype: int64
#
# % de valores nulos por coluna:
# PrincessName                   0.00
# FirstMovieTitle                0.00
# FirstMovieYear                 0.00
# MovieRuntimeMinutes            0.00
# NumberOfSongs                  0.00
# HasSoloSong                    0.00
# HasDuet                        0.00
# HairColor                      0.00
# EyeColor                       0.00
# OutfitPrimaryColor             0.00
# OutfitStyleEra                 0.00
# IsRoyalByBirth                 0.00
# HasAnimalSidekick              0.00
# SidekickType                  23.33
# HasMagicalPowers               0.00
# MagicType                     17.67
# MainSetting                    0.00
# IsBasedOnRealStory             0.00
# CulturalOrigin                 0.00
# SpeaksToAnimals                0.00
# FightsVillainDirectly          0.00
# RomanticSubplot                0.00
# MarriedByEnd                   0.00
# VillainName                    0.00
# VillainType                   15.67
# IMDB_Rating                    0.00
# RottenTomatoesScore            0.00
# BoxOfficeMillions              0.00
# AvgScreenTimeMinutes           0.00
# NumMerchItemsOnAmazon          0.00
# GoogleSearchIndex2024          0.00
# InstagramFanPages              0.00
# TikTokHashtagViewsMillions     0.00
# Top3Hashtags                   0.00
# IsIconic                       0.00
# PopularityScore                0.00
# dtype: float64
#
# Estatísticas descritivas (colunas numéricas):
#        FirstMovieYear  MovieRuntimeMinutes  NumberOfSongs  IMDB_Rating  \
# count      300.000000           300.000000     300.000000   300.000000
# mean      1980.243333            90.913333       3.993333     7.466667
# std         24.621227            11.726502       2.149890     0.863311
# min       1937.000000            70.000000       1.000000     6.000000
# 25%       1959.750000            80.000000       2.000000     6.700000
# 50%       1983.000000            91.000000       4.000000     7.400000
# 75%       2000.250000           101.000000       6.000000     8.200000
# max       2021.000000           110.000000       7.000000     9.000000
#
#        RottenTomatoesScore  BoxOfficeMillions  AvgScreenTimeMinutes  \
# count           300.000000         300.000000            300.000000
# mean             80.650000         700.843333             40.616667
# std              10.996237         346.922618             11.575680
# min              60.000000         101.000000             20.000000
# 25%              71.750000         392.000000             31.750000
# 50%              80.000000         709.500000             41.000000
# 75%              90.000000         997.250000             51.000000
# max             100.000000        1300.000000             60.000000
#
#        NumMerchItemsOnAmazon  GoogleSearchIndex2024  InstagramFanPages  \
# count             300.000000             300.000000         300.000000
# mean             2467.270000              61.300000         152.063333
# std              1469.301225              22.393785          83.929214
# min                61.000000              20.000000          10.000000
# 25%              1223.500000              41.750000          75.750000
# 50%              2357.500000              61.000000         148.500000
# 75%              3743.250000              81.000000         227.250000
# max              4998.000000             100.000000         300.000000
#
#        TikTokHashtagViewsMillions  PopularityScore
# count                  300.000000       300.000000
# mean                   506.870000        75.130000
# std                    292.751278        14.293382
# min                     10.000000        50.000000
# 25%                    236.500000        63.000000
# 50%                    524.500000        75.000000
# 75%                    781.250000        87.000000
# max                    999.000000       100.000000
#
# Estatísticas descritivas (colunas categóricas):
#        PrincessName    FirstMovieTitle HasSoloSong HasDuet HairColor EyeColor  \
# count           300                300         300     300       300      300
# unique           15                 15           2       2         5        5
# top           Mulan  Mulan's Adventure          No     Yes    Blonde    Brown
# freq             29                 29         167     153        64       69
#
#        OutfitPrimaryColor OutfitStyleEra IsRoyalByBirth HasAnimalSidekick  \
# count                 300            300            300               300
# unique                  5              4              2                 2
# top                Yellow      Victorian            Yes               Yes
# freq                   68             89            155               155
#
#         ... IsBasedOnRealStory    CulturalOrigin SpeaksToAnimals  \
# count   ...                300               300             300
# unique  ...                  2                 8               2
# top     ...                Yes  African-American              No
# freq    ...                155                44             162
#
#        FightsVillainDirectly RomanticSubplot MarriedByEnd       VillainName  \
# count                    300             300          300               300
# unique                     2               2            2                15
# top                       No             Yes          Yes  Villain of Mulan
# freq                     153             155          162                29
#
#        VillainType                         Top3Hashtags IsIconic
# count          253                                  300      300
# unique           5                                   15        2
# top          Witch  #TeamMulan #LoveMulan #MulanForever      Yes
# freq            67                                   29      154
#
# [4 rows x 24 columns]
#
# Valores únicos por coluna categórica:
#
# Coluna 'PrincessName' - 15 valores únicos:
# ['Pocahontas' 'Mulan' 'Raya' 'Anna' 'Jasmine' 'Snow White' 'Rapunzel'
#  'Belle' 'Cinderella' 'Ariel' 'Elsa' 'Aurora' 'Moana' 'Tiana' 'Merida']
#
# Coluna 'FirstMovieTitle' - 15 valores únicos:
# ["Pocahontas's Adventure" "Mulan's Adventure" "Raya's Adventure"
#  "Anna's Adventure" "Jasmine's Adventure" "Snow White's Adventure"
#  "Rapunzel's Adventure" "Belle's Adventure" "Cinderella's Adventure"
#  "Ariel's Adventure" "Elsa's Adventure" "Aurora's Adventure"
#  "Moana's Adventure" "Tiana's Adventure" "Merida's Adventure"]
#
# Coluna 'HasSoloSong' - 2 valores únicos:
# ['No' 'Yes']
#
# Coluna 'HasDuet' - 2 valores únicos:
# ['Yes' 'No']
#
# Coluna 'HairColor' - 5 valores únicos:
# ['Brown' 'Blonde' 'White' 'Black' 'Red']
#
# Coluna 'EyeColor' - 5 valores únicos:
# ['Green' 'Brown' 'Hazel' 'Grey' 'Blue']
#
# Coluna 'OutfitPrimaryColor' - 5 valores únicos:
# ['Pink' 'Purple' 'Green' 'Blue' 'Yellow']
#
# Coluna 'OutfitStyleEra' - 4 valores únicos:
# ['Victorian' 'Ancient' 'Modern' 'Medieval']
#
# Coluna 'IsRoyalByBirth' - 2 valores únicos:
# ['Yes' 'No']
#
# Coluna 'HasAnimalSidekick' - 2 valores únicos:
# ['Yes' 'No']
#
# Coluna 'SidekickType' - 3 valores únicos:
# ['Dragon' 'Horse' 'Fish' nan]
#
# Coluna 'HasMagicalPowers' - 2 valores únicos:
# ['Yes' 'No']
#
# Coluna 'MagicType' - 5 valores únicos:
# [nan 'Ice' 'Healing' 'Dragon' 'Ocean' 'Voice']
#
# Coluna 'MainSetting' - 6 valores únicos:
# ['Forest' 'Mountains' 'Desert' 'Village' 'Castle' 'Ocean']
#
# Coluna 'IsBasedOnRealStory' - 2 valores únicos:
# ['Yes' 'No']
#
# Coluna 'CulturalOrigin' - 8 valores únicos:
# ['Scottish' 'Native American' 'Polynesian' 'Arabian' 'Chinese'
#  'African-American' 'Nordic' 'French']
#
# Coluna 'SpeaksToAnimals' - 2 valores únicos:
# ['No' 'Yes']
#
# Coluna 'FightsVillainDirectly' - 2 valores únicos:
# ['Yes' 'No']
#
# Coluna 'RomanticSubplot' - 2 valores únicos:
# ['No' 'Yes']
#
# Coluna 'MarriedByEnd' - 2 valores únicos:
# ['No' 'Yes']
#
# Coluna 'VillainName' - 15 valores únicos:
# ['Villain of Pocahontas' 'Villain of Mulan' 'Villain of Raya'
#  'Villain of Anna' 'Villain of Jasmine' 'Villain of Snow White'
#  'Villain of Rapunzel' 'Villain of Belle' 'Villain of Cinderella'
#  'Villain of Ariel' 'Villain of Elsa' 'Villain of Aurora'
#  'Villain of Moana' 'Villain of Tiana' 'Villain of Merida']
#
# Coluna 'VillainType' - 5 valores únicos:
# ['Witch' 'Stepmother' 'Sorcerer' 'Warlord' 'Hunter' nan]
#
# Coluna 'Top3Hashtags' - 15 valores únicos:
# ['#TeamPocahontas #LovePocahontas #PocahontasForever'
#  '#TeamMulan #LoveMulan #MulanForever' '#TeamRaya #LoveRaya #RayaForever'
#  '#TeamAnna #LoveAnna #AnnaForever'
#  '#TeamJasmine #LoveJasmine #JasmineForever'
#  '#TeamSnow White #LoveSnow White #Snow WhiteForever'
#  '#TeamRapunzel #LoveRapunzel #RapunzelForever'
#  '#TeamBelle #LoveBelle #BelleForever'
#  '#TeamCinderella #LoveCinderella #CinderellaForever'
#  '#TeamAriel #LoveAriel #ArielForever' '#TeamElsa #LoveElsa #ElsaForever'
#  '#TeamAurora #LoveAurora #AuroraForever'
#  '#TeamMoana #LoveMoana #MoanaForever'
#  '#TeamTiana #LoveTiana #TianaForever'
#  '#TeamMerida #LoveMerida #MeridaForever']
#
# Coluna 'IsIconic' - 2 valores únicos:
# ['Yes' 'No']
#
# Registros duplicados (linhas inteiras): 0
#
# Colunas com valores únicos em todas as linhas (possíveis IDs):

# %% [markdown]
# # **Resultado da análise exploratória**
# * dataset possui 300 linhas e 36 colunas.
# * temos 24 colunas do tipo object (categóricas ou textuais), 11 colunas do tipo int64 (numéricas inteiras) e 1 do tipo float64 (IMDB_Rating).
#
# Há valores nulos nas seguintes colunas:
# * SidekickType: 23,33% de valores ausentes
# * MagicType: 17,67% de valores ausentes
# * VillainType: 15,67% de valores ausentes
#
# ### **IMPORTANTE!**
# Essas colunas precisarão de tratamento específico, como imputação, categorização de ausentes ou exclusão.
#
# A análise exploratória também revela a importância de verificar:
#
# Colunas booleanas codificadas como object **precisarão ser convertidas em booleanas reais para facilitar as expectativas com Great Expectations.**

# %% [markdown]
# ## **Usando o Great Expectations para ETL**

# %% [markdown]
# ### O que vamos fazer com o great_expectations:
#
# 1. verificar a distribuição de valores únicos em colunas categóricas (como HairColor, OutfitStyleEra, CulturalOrigin, VillainType), que serão úteis para aplicar expectativas como expect_column_values_to_be_in_set.
#
# 2. Consistência entre colunas relacionadas:
#
# * Se HasAnimalSidekick for False, SidekickType deve ser nulo
#
# * Se HasMagicalPowers for False, MagicType deve ser nulo
#
# * Se IsBasedOnRealStory for True, talvez MagicType devesse ser nulo (ou investigar exceções)
#
# 3. A necessidade de expectativas relacionadas à completude dos dados em colunas críticas, como expect_column_values_to_not_be_null
#
# 4. Detecção de outliers em colunas como TikTokHashtagViewsMillions, BoxOfficeMillions e PopularityScore
#
# 5. Relações de correlação entre PopularityScore e métricas como InstagramFanPages, IMDB_Rating, e GoogleSearchIndex2024, que podem embasar regras para detecção de anomalias futuras

# %% [markdown]
# # Instalando Great_Expectations

# %%
# !pip install great_expectations==0.17.21
import great_expectations as ge

# contexto
context = ge.get_context()

# Adiciona um datasource do tipo pandas
datasource = context.sources.add_pandas(name="datasource")

# Adiciona o asset com o DataFrame
asset = datasource.add_dataframe_asset(name="DisneyPrincess", dataframe=df)

# Cria o batch request
batch_request = asset.build_batch_request()
# Out:
# Requirement already satisfied: great_expectations==0.17.21 in /usr/local/lib/python3.11/dist-packages (0.17.21)
# Requirement already satisfied: altair<5.0.0,>=4.2.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (4.2.2)
# Requirement already satisfied: Click!=8.1.4,>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (8.1.8)
# Requirement already satisfied: colorama>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (0.4.6)
# Requirement already satisfied: cryptography>=3.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (43.0.3)
# Requirement already satisfied: Ipython>=7.16.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (7.34.0)
# Requirement already satisfied: ipywidgets>=7.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (7.7.1)
# Requirement already satisfied: jinja2>=2.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (3.1.6)
# Requirement already satisfied: jsonpatch>=1.22 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (1.33)
# Requirement already satisfied: jsonschema>=2.5.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (4.23.0)
# Requirement already satisfied: makefun<2,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (1.15.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.7.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (3.26.1)
# Requirement already satisfied: mistune>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (3.1.3)
# Requirement already satisfied: nbformat>=5.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (5.10.4)
# Requirement already satisfied: notebook>=6.4.10 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (6.5.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (24.2)
# Requirement already satisfied: pydantic>=1.9.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (2.11.3)
# Requirement already satisfied: pyparsing>=2.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (2.9.0.post0)
# Requirement already satisfied: pytz>=2021.3 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (2025.2)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (2.32.3)
# Requirement already satisfied: ruamel.yaml<0.17.18,>=0.16 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (0.17.17)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (1.15.2)
# Requirement already satisfied: tqdm>=4.59.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (4.13.2)
# Requirement already satisfied: tzlocal>=1.2 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (5.3.1)
# Requirement already satisfied: urllib3>=1.26 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (2.4.0)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (1.26.4)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from great_expectations==0.17.21) (2.1.4)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.11/dist-packages (from altair<5.0.0,>=4.2.1->great_expectations==0.17.21) (0.4)
# Requirement already satisfied: toolz in /usr/local/lib/python3.11/dist-packages (from altair<5.0.0,>=4.2.1->great_expectations==0.17.21) (0.12.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.2->great_expectations==0.17.21) (1.17.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from Ipython>=7.16.3->great_expectations==0.17.21) (4.9.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.17.21) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.17.21) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.17.21) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from ipywidgets>=7.5.1->great_expectations==0.17.21) (3.0.14)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2>=2.10->great_expectations==0.17.21) (3.0.2)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.11/dist-packages (from jsonpatch>=1.22->great_expectations==0.17.21) (3.0.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.17.21) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.17.21) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.17.21) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.11/dist-packages (from jsonschema>=2.5.1->great_expectations==0.17.21) (0.24.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations==0.17.21) (2.21.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.11/dist-packages (from nbformat>=5.0->great_expectations==0.17.21) (5.7.2)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (6.4.2)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (23.1.0)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (6.1.12)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (7.16.6)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (0.21.1)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.11/dist-packages (from notebook>=6.4.10->great_expectations==0.17.21) (1.3.0)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.3.0->great_expectations==0.17.21) (2025.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->great_expectations==0.17.21) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->great_expectations==0.17.21) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic>=1.9.2->great_expectations==0.17.21) (0.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.1->great_expectations==0.17.21) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations==0.17.21) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations==0.17.21) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.20->great_expectations==0.17.21) (2025.1.31)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.2->great_expectations==0.17.21) (2.22)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations==0.17.21) (1.8.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.1->great_expectations==0.17.21) (5.9.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->Ipython>=7.16.3->great_expectations==0.17.21) (0.8.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.11/dist-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=5.0->great_expectations==0.17.21) (4.3.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.17.21) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.17.21) (4.13.4)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations==0.17.21) (6.2.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.17.21) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.17.21) (0.3.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.17.21) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.11/dist-packages (from nbconvert>=5->notebook>=6.4.10->great_expectations==0.17.21) (1.5.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->Ipython>=7.16.3->great_expectations==0.17.21) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->Ipython>=7.16.3->great_expectations==0.17.21) (0.2.13)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.11/dist-packages (from argon2-cffi->notebook>=6.4.10->great_expectations==0.17.21) (21.2.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations==0.17.21) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.4.10->great_expectations==0.17.21) (1.4.0)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.11/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.17.21) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.4.10->great_expectations==0.17.21) (2.7)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.17.21) (4.9.0)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.11/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.17.21) (1.8.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.11/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.4.10->great_expectations==0.17.21) (1.3.1)
# INFO:great_expectations.data_context.types.base:Created temporary directory '/tmp/tmpwcvw6zte' for ephemeral docs site

# %%
# Colunas que NÃO PODEM TER VALORES NULOS
expect_column_values_to_not_be_null('PrincessName')
expect_column_values_to_not_be_null('PopularityScore')
expect_column_values_to_not_be_null('BoxOfficeRevenue')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-dc65bed8165d> in <cell line: 0>()
#       1 # Colunas que NÃO PODEM TER VALORES NULOS
# ----> 2 expect_column_values_to_not_be_null('PrincessName')
#       3 expect_column_values_to_not_be_null('PopularityScore')
#       4 expect_column_values_to_not_be_null('BoxOfficeRevenue')
#
# NameError: name 'expect_column_values_to_not_be_null' is not defined
